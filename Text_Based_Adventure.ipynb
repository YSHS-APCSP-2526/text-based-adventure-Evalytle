# %% [markdown]
# <a href="https://colab.research.google.com/github/YSHS-APCSP-2526/text-based-adventure-Evalytle/blob/main/Text_Based_Adventure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Requirements for text based adventure
# 1. You must have at least 2 different "paths" that are at least 4 decisions in length
# 2. Include an element of randomness (from the random library)
# 3. Include a list that is core to the text based adventure
# 4. Include a function that is called within your program that includes a while loop, and a parameter that influences a conditional statement in your function.
# 5. Commented Code.
# 6. A [digital flowchart](https://docs.google.com/document/d/1p2k3wL6gzjYWBuWxwEQptmbbOZZNsQrthlC12SNtYgY/edit?usp=sharing) that follows accepted symbols for representing code. You can use google slides or [draw.io](https://www.drawio.com/) for the flowchart.

# %%
def intro():
  response = input('Oh no there was an zombie outbreak, you have three lives so use them wisely! What would you like to do? (Find citization or gather materials around you)')
  return response

# %%
def choice1():
  response = intro()
  if response =='Find citization':
    print('You found a city! But it seems a little too quiet so be careful! Where to now? (Explore shipwreck or enter abandoned hospital)')
  elif response =='gather materials around you':
    print('You found an axe and some food! What would want to do now? (Find citization)')
  else:
    print('I am sorry, I do not understand where you want to go. Please try again')

# %%
def choice2():
  response2 = choice1()
  if response2 =='Explore shipwreck':
    print('You find and worned down radio and a med kit,but you seem to have gotten stuck in some netting!(Try to free yourself or attempt to reach a broken shard of glass to cut yourself free)')
  elif response2 =='enter abandoned hospital' and response =='Find civilzation':
    print('Watch out! A zombie appeared in front of you! Sadly you did not have a weapon to defend your self... (-1 life) To regain your lost life (use the medkit, but you will not be able to use it again, explore the hospital more, or exit)')
  elif response2 =='Find citization':
    print('You found a city! But it seems a little too quiet so be careful! Where to now? (Explore shipwreck or enter abandoned hospital)')
  else:
    print('I am sorry, I do not understand where you want to go. Please try again')

# %%
def choice3():
  response3 = choice2()
  if response3 =='Explore shipwreck':
    print('You find and worned down radio and a med kit,but you seem to have gotten stuck in some netting!')
  elif response3 =='enter abandoned hospital' and response =='gather materials around you':
    print('Watch out! A zombie appeared in front of you, use your axe to defend yourself!')
  elif response3 =='enter abandoned hospital' and response =='Find civilzation'and response2 =='Explore shipwreck':
    print('Watch out! A zombie appeared in front of you! Sadly you did not have a weapon to defend your self... (-1 life) To regain your lost life (use the medkit, but you will not be able to use it again, explore the hospital more, or exit)')
  elif response3 =='enter abandoned hospital' and response =='Find civilzation':
    print('Watch out! A zombie appeared in front of you! Sadly you did not have a weapon to defend your self... (-1 life) You can not regain your lost life (explore the hospital more or exit)')
  elif response3 =='use the medkit, but you will not be able to use it again':
    print('Congrats you regained your life! Where to next? (Enter hospital laboratory or leave hospital)')
  elif response3 =='Try to free yourself':
    print('You attempt to free yourself but fail (-1 life) (use the medkit to regain your lost life, but you will not be able to use it again or continue')
  elif reponse3 =='attempt to reach a broken shard of glass to cut yourself free':
    print('You managed to grab the glass escape, but also accidently cut yourself so be extra cautionus the zombies will be able to find you easier now. Where is our next destination? (abandoned hosptial or walk down the city street)')
  elif response3 =='explore the hospital more':
    print('you find two medkits and and glowing substance labeled "Half of Antidote"! Where to now? (walk down the city street)')
  elif response3 =='exit':
    print('There does not seem to be anymore place of interest here best to continue on. Where to now? (walk down the city street)')
  else:
    print('I am sorry, I do not understand where you want to go. Please try again')

# %%
def choice4():
  response4 = choice3()
  if response4 =='walk down the city street':
    print('')
  elif response4 =='continue':
    print('')
  elif response4 =='abandoned hosptial':
    print('')
  elif response4 =='exit':
    print('')
  else:
    print('I am sorry, I do not understand where you want to go. Please try again')

# %%
def main():
  response =intro()
  choice1(response)
  choice2(response2)
  choice3(response3)
  choice4(response4)

# %%
main()
# Out:
# Oh no there was an zombie outbreak, you have three lives so use them wisely! What would you like to do? (Find citization or gather materials around you)Find civization
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-451043146.py in <cell line: 0>()
# ----> 1 main()
#
# /tmp/ipython-input-1159100198.py in main()
#       1 def main():
#       2   response =intro()
# ----> 3   choice1(response)
#       4   choice2(response2)
#       5   choice3(response3)
#
# TypeError: choice1() takes 0 positional arguments but 1 was given

# %%
x = 0

while x<5:
  print('hello')
  x = x
# Out:
# Streaming output truncated to the last 5000 lines.
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# ...

# %%
def responseValidator(response):
  while response != 'yes' and respoense !='no':
    response = input('Invalid Response: please type yes or no')
  return response

# %%
responseValidator("no")
